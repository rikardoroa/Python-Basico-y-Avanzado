# %%
#DataFrame Styles
#script by @rikardoroa
#just Python it!

import pandas as pd
import numpy as np


class data:
    
    def __init__(self, Data = pd.DataFrame):
        self.Data = Data
   

        
    @classmethod
    def create_dataframes(self):
        Random = np.random.randn(6)
        Random_2 = np.random.randn(6)
        Random_choise = np.random.randint(5, size=(6))
        Date_Data = pd.DataFrame(["2021-02-01","2021-02-02",
                                  "2021-02-03","2021-02-04","2021-02-05","2021-02-06"],columns={"D"})
        Data = pd.DataFrame(Random_choise, columns=["A"])
        Data = pd.concat([Data, pd.DataFrame(Random, columns=list("B"))],axis=1)
        Data = pd.concat([Data, pd.DataFrame(Random_2, columns=list("C"))],axis=1)
        Data = pd.concat([Data, pd.DataFrame(Date_Data, columns=list("D"))],axis=1)
        self.Data = Data
        return Data
 

    @classmethod
    def boolean_exploration(self):
        Data = self.Data
        return Data[["B"]]<0
    
    
    def mask_y(x):
        yellow = "background-color:yellow"
        mask= x["B"]<0
        d = pd.DataFrame('', x.index,x.columns)
        d.loc[mask,:] = yellow
        return d
    
    
    def mask_g(x):
        green = "background-color:#81df81"
        mask= x["A"]>0
        d = pd.DataFrame('', x.index, x.columns)
        d.loc[mask,:] = green
        return d
    
    
    
    def mask_o_y(x):
        yellow = "background-color:yellow"
        orange = "background-color:#F5C48F"
        mask= x["B"]<0
        mask2= x["B"]>0
        d = pd.DataFrame('', x.index, x.columns)
        d.loc[mask,:] = yellow
        d.loc[mask2,:] = orange
        return d
    
       
    @staticmethod
    def apply_mask_y(): 
        return data.create_dataframes().style.apply(data.mask_y, axis=None,subset=["B"])
    
    
    @staticmethod
    def apply_mask_g(): 
        return data.create_dataframes().style.apply(data.mask_g, axis=None,subset=["A"])
       
        
    @staticmethod
    def apply_mask_o_y(): 
        return data.create_dataframes().style.apply(data.mask_o_y, axis=None,subset=["B"])
    
    
    
    @classmethod
    def background_yellow(self):
        return self.Data.loc[self.Data["B"]<0].style.set_properties(**{'background-color': 'yellow'} ,subset=['B'])
    
    
    
    @classmethod
    def background_yellow_lambda_exp(self):
        yellow =  self.Data.loc[lambda x : x["B"]<0].style.set_properties(**{'background-color': 'yellow'} ,subset=['B'])
        return yellow
  

    def background_values(x):
        color=''
        if x < 0:
            color = 'background-color:yellow'
            return color
        if x >= 2:
            color = 'background-color:red'
            return color
        if x > 0:
            color = 'background-color:#F5C48F'
            return color
        if x == 0:
            color = 'background-color:orange'
            return color

    @staticmethod
    def apply_mask_background_colors():
        return data.create_dataframes().style.applymap(data.background_values,subset=["A","B","C"])
    
    
    @staticmethod
    def apply_mask_background_colors_to_excel():
        return data.create_dataframes().style.applymap(data.background_values,subset=["A","B","C"]).to_excel(r"D:\output.xlsx")

# %%
data.create_dataframes()
# Out:
#    A         B         C           D
# 0  2  1.536741  0.282627  2021-02-01
# 1  2  0.181019 -0.357069  2021-02-02
# 2  4  0.479637 -0.802933  2021-02-03
# 3  2 -0.121699  0.430697  2021-02-04
# 4  4 -1.648424 -0.932856  2021-02-05
# 5  0 -1.865694  0.599199  2021-02-06

# %%
data.boolean_exploration()
# Out:
#        B
# 0  False
# 1  False
# 2  False
# 3   True
# 4   True
# 5   True

# %%
data.apply_mask_y()
# Out:
# <style  type="text/css" >
# #T_5f3c0_row1_col1,#T_5f3c0_row2_col1,#T_5f3c0_row3_col1{
#             background-color: yellow;
#         }</style><table id="T_5f3c0_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >A</th>        <th class="col_heading level0 col1" >B</th>        <th class="col_heading level0 col2" >C</th>        <th class="col_heading level0 col3" >D</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5f3c0_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_5f3c0_row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_5f3c0_row0_col1" class="data row0 col1" >0.139536</td>
#                         <td id="T_5f3c0_row0_col2" class="data row0 col2" >1.626640</td>
#                         <td id="T_5f3c0_row0_col3" class="data row0 col3" >2021-02-01</td>
#             </tr>
#             <tr>
#                         <th id="T_5f3c0_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_5f3c0_row1_col0" class="data row1 col0" >4</td>
#                         <td id="T_5f3c0_row1_col1" class="data row1 col1" >-2.703276</td>
#                         <td id="T_5f3c0_row1_col2" class="data row1 col2" >-0.132675</td>
#                         <td id="T_5f3c0_row1_col3" class="data row1 col3" >2021-02-02</td>
#             </tr>
#             <tr>
#                         <th id="T_5f3c0_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_5f3c0_row2_col0" class="data row2 col0" >2</td>
#                         <td id="T_5f3c0_row2_col1" class="data row2 col1" >-0.984608</td>
#                         <td id="T_5f3c0_row2_col2" class="data row2 col2" >-2.192683</td>
#                         <td id="T_5f3c0_row2_col3" class="data row2 col3" >2021-02-03</td>
#             </tr>
#             <tr>
#                         <th id="T_5f3c0_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_5f3c0_row3_col0" class="data row3 col0" >2</td>
#                         <td id="T_5f3c0_row3_col1" class="data row3 col1" >-1.862485</td>
#                         <td id="T_5f3c0_row3_col2" class="data row3 col2" >1.838879</td>
#                         <td id="T_5f3c0_row3_col3" class="data row3 col3" >2021-02-04</td>
#             </tr>
#             <tr>
#                         <th id="T_5f3c0_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_5f3c0_row4_col0" class="data row4 col0" >1</td>
#                         <td id="T_5f3c0_row4_col1" class="data row4 col1" >1.161529</td>
#                         <td id="T_5f3c0_row4_col2" class="data row4 col2" >-2.181582</td>
#                         <td id="T_5f3c0_row4_col3" class="data row4 col3" >2021-02-05</td>
#             </tr>
#             <tr>
#                         <th id="T_5f3c0_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_5f3c0_row5_col0" class="data row5 col0" >3</td>
#                         <td id="T_5f3c0_row5_col1" class="data row5 col1" >1.246905</td>
#                         <td id="T_5f3c0_row5_col2" class="data row5 col2" >-0.011365</td>
#                         <td id="T_5f3c0_row5_col3" class="data row5 col3" >2021-02-06</td>
#             </tr>
#     </tbody></table>

# %%
data.apply_mask_g()
# Out:
# <style  type="text/css" >
# #T_e7151_row0_col0,#T_e7151_row1_col0,#T_e7151_row2_col0,#T_e7151_row5_col0{
#             background-color: #81df81;
#         }</style><table id="T_e7151_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >A</th>        <th class="col_heading level0 col1" >B</th>        <th class="col_heading level0 col2" >C</th>        <th class="col_heading level0 col3" >D</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e7151_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e7151_row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_e7151_row0_col1" class="data row0 col1" >-0.036719</td>
#                         <td id="T_e7151_row0_col2" class="data row0 col2" >-0.882577</td>
#                         <td id="T_e7151_row0_col3" class="data row0 col3" >2021-02-01</td>
#             </tr>
#             <tr>
#                         <th id="T_e7151_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_e7151_row1_col0" class="data row1 col0" >2</td>
#                         <td id="T_e7151_row1_col1" class="data row1 col1" >0.654630</td>
#                         <td id="T_e7151_row1_col2" class="data row1 col2" >0.330750</td>
#                         <td id="T_e7151_row1_col3" class="data row1 col3" >2021-02-02</td>
#             </tr>
#             <tr>
#                         <th id="T_e7151_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_e7151_row2_col0" class="data row2 col0" >3</td>
#                         <td id="T_e7151_row2_col1" class="data row2 col1" >0.925090</td>
#                         <td id="T_e7151_row2_col2" class="data row2 col2" >-0.416885</td>
#                         <td id="T_e7151_row2_col3" class="data row2 col3" >2021-02-03</td>
#             </tr>
#             <tr>
#                         <th id="T_e7151_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_e7151_row3_col0" class="data row3 col0" >0</td>
#                         <td id="T_e7151_row3_col1" class="data row3 col1" >0.329584</td>
#                         <td id="T_e7151_row3_col2" class="data row3 col2" >2.209188</td>
#                         <td id="T_e7151_row3_col3" class="data row3 col3" >2021-02-04</td>
#             </tr>
#             <tr>
#                         <th id="T_e7151_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_e7151_row4_col0" class="data row4 col0" >0</td>
#                         <td id="T_e7151_row4_col1" class="data row4 col1" >-2.158419</td>
#                         <td id="T_e7151_row4_col2" class="data row4 col2" >2.065801</td>
#                         <td id="T_e7151_row4_col3" class="data row4 col3" >2021-02-05</td>
#             </tr>
#             <tr>
#                         <th id="T_e7151_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_e7151_row5_col0" class="data row5 col0" >2</td>
#                         <td id="T_e7151_row5_col1" class="data row5 col1" >-0.304516</td>
#                         <td id="T_e7151_row5_col2" class="data row5 col2" >-0.699955</td>
#                         <td id="T_e7151_row5_col3" class="data row5 col3" >2021-02-06</td>
#             </tr>
#     </tbody></table>

# %%
data.apply_mask_o_y()
# Out:
# <style  type="text/css" >
# #T_0a1ec_row0_col1,#T_0a1ec_row1_col1,#T_0a1ec_row4_col1,#T_0a1ec_row5_col1{
#             background-color: yellow;
#         }#T_0a1ec_row2_col1,#T_0a1ec_row3_col1{
#             background-color: #F5C48F;
#         }</style><table id="T_0a1ec_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >A</th>        <th class="col_heading level0 col1" >B</th>        <th class="col_heading level0 col2" >C</th>        <th class="col_heading level0 col3" >D</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0a1ec_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_0a1ec_row0_col0" class="data row0 col0" >2</td>
#                         <td id="T_0a1ec_row0_col1" class="data row0 col1" >-0.355447</td>
#                         <td id="T_0a1ec_row0_col2" class="data row0 col2" >0.494547</td>
#                         <td id="T_0a1ec_row0_col3" class="data row0 col3" >2021-02-01</td>
#             </tr>
#             <tr>
#                         <th id="T_0a1ec_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_0a1ec_row1_col0" class="data row1 col0" >0</td>
#                         <td id="T_0a1ec_row1_col1" class="data row1 col1" >-0.198722</td>
#                         <td id="T_0a1ec_row1_col2" class="data row1 col2" >-1.739012</td>
#                         <td id="T_0a1ec_row1_col3" class="data row1 col3" >2021-02-02</td>
#             </tr>
#             <tr>
#                         <th id="T_0a1ec_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_0a1ec_row2_col0" class="data row2 col0" >2</td>
#                         <td id="T_0a1ec_row2_col1" class="data row2 col1" >0.397268</td>
#                         <td id="T_0a1ec_row2_col2" class="data row2 col2" >-1.087833</td>
#                         <td id="T_0a1ec_row2_col3" class="data row2 col3" >2021-02-03</td>
#             </tr>
#             <tr>
#                         <th id="T_0a1ec_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_0a1ec_row3_col0" class="data row3 col0" >4</td>
#                         <td id="T_0a1ec_row3_col1" class="data row3 col1" >0.733255</td>
#                         <td id="T_0a1ec_row3_col2" class="data row3 col2" >-1.893288</td>
#                         <td id="T_0a1ec_row3_col3" class="data row3 col3" >2021-02-04</td>
#             </tr>
#             <tr>
#                         <th id="T_0a1ec_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_0a1ec_row4_col0" class="data row4 col0" >4</td>
#                         <td id="T_0a1ec_row4_col1" class="data row4 col1" >-0.673725</td>
#                         <td id="T_0a1ec_row4_col2" class="data row4 col2" >-1.291382</td>
#                         <td id="T_0a1ec_row4_col3" class="data row4 col3" >2021-02-05</td>
#             </tr>
#             <tr>
#                         <th id="T_0a1ec_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_0a1ec_row5_col0" class="data row5 col0" >0</td>
#                         <td id="T_0a1ec_row5_col1" class="data row5 col1" >-0.325528</td>
#                         <td id="T_0a1ec_row5_col2" class="data row5 col2" >0.328648</td>
#                         <td id="T_0a1ec_row5_col3" class="data row5 col3" >2021-02-06</td>
#             </tr>
#     </tbody></table>

# %%
data.background_yellow()
# Out:
# <style  type="text/css" >
# #T_b6118_row0_col1,#T_b6118_row1_col1,#T_b6118_row2_col1,#T_b6118_row3_col1{
#             background-color:  yellow;
#         }</style><table id="T_b6118_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >A</th>        <th class="col_heading level0 col1" >B</th>        <th class="col_heading level0 col2" >C</th>        <th class="col_heading level0 col3" >D</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b6118_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b6118_row0_col0" class="data row0 col0" >2</td>
#                         <td id="T_b6118_row0_col1" class="data row0 col1" >-0.355447</td>
#                         <td id="T_b6118_row0_col2" class="data row0 col2" >0.494547</td>
#                         <td id="T_b6118_row0_col3" class="data row0 col3" >2021-02-01</td>
#             </tr>
#             <tr>
#                         <th id="T_b6118_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b6118_row1_col0" class="data row1 col0" >0</td>
#                         <td id="T_b6118_row1_col1" class="data row1 col1" >-0.198722</td>
#                         <td id="T_b6118_row1_col2" class="data row1 col2" >-1.739012</td>
#                         <td id="T_b6118_row1_col3" class="data row1 col3" >2021-02-02</td>
#             </tr>
#             <tr>
#                         <th id="T_b6118_level0_row2" class="row_heading level0 row2" >4</th>
#                         <td id="T_b6118_row2_col0" class="data row2 col0" >4</td>
#                         <td id="T_b6118_row2_col1" class="data row2 col1" >-0.673725</td>
#                         <td id="T_b6118_row2_col2" class="data row2 col2" >-1.291382</td>
#                         <td id="T_b6118_row2_col3" class="data row2 col3" >2021-02-05</td>
#             </tr>
#             <tr>
#                         <th id="T_b6118_level0_row3" class="row_heading level0 row3" >5</th>
#                         <td id="T_b6118_row3_col0" class="data row3 col0" >0</td>
#                         <td id="T_b6118_row3_col1" class="data row3 col1" >-0.325528</td>
#                         <td id="T_b6118_row3_col2" class="data row3 col2" >0.328648</td>
#                         <td id="T_b6118_row3_col3" class="data row3 col3" >2021-02-06</td>
#             </tr>
#     </tbody></table>

# %%
data.background_yellow_lambda_exp()
# Out:
# <style  type="text/css" >
# #T_e6e99_row0_col1,#T_e6e99_row1_col1,#T_e6e99_row2_col1,#T_e6e99_row3_col1{
#             background-color:  yellow;
#         }</style><table id="T_e6e99_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >A</th>        <th class="col_heading level0 col1" >B</th>        <th class="col_heading level0 col2" >C</th>        <th class="col_heading level0 col3" >D</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e6e99_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e6e99_row0_col0" class="data row0 col0" >2</td>
#                         <td id="T_e6e99_row0_col1" class="data row0 col1" >-0.355447</td>
#                         <td id="T_e6e99_row0_col2" class="data row0 col2" >0.494547</td>
#                         <td id="T_e6e99_row0_col3" class="data row0 col3" >2021-02-01</td>
#             </tr>
#             <tr>
#                         <th id="T_e6e99_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_e6e99_row1_col0" class="data row1 col0" >0</td>
#                         <td id="T_e6e99_row1_col1" class="data row1 col1" >-0.198722</td>
#                         <td id="T_e6e99_row1_col2" class="data row1 col2" >-1.739012</td>
#                         <td id="T_e6e99_row1_col3" class="data row1 col3" >2021-02-02</td>
#             </tr>
#             <tr>
#                         <th id="T_e6e99_level0_row2" class="row_heading level0 row2" >4</th>
#                         <td id="T_e6e99_row2_col0" class="data row2 col0" >4</td>
#                         <td id="T_e6e99_row2_col1" class="data row2 col1" >-0.673725</td>
#                         <td id="T_e6e99_row2_col2" class="data row2 col2" >-1.291382</td>
#                         <td id="T_e6e99_row2_col3" class="data row2 col3" >2021-02-05</td>
#             </tr>
#             <tr>
#                         <th id="T_e6e99_level0_row3" class="row_heading level0 row3" >5</th>
#                         <td id="T_e6e99_row3_col0" class="data row3 col0" >0</td>
#                         <td id="T_e6e99_row3_col1" class="data row3 col1" >-0.325528</td>
#                         <td id="T_e6e99_row3_col2" class="data row3 col2" >0.328648</td>
#                         <td id="T_e6e99_row3_col3" class="data row3 col3" >2021-02-06</td>
#             </tr>
#     </tbody></table>

# %%
data.apply_mask_background_colors()
# Out:
# <style  type="text/css" >
# #T_6ac7e_row0_col0,#T_6ac7e_row4_col0{
#             background-color: red;
#         }#T_6ac7e_row0_col1,#T_6ac7e_row0_col2,#T_6ac7e_row2_col2,#T_6ac7e_row4_col1,#T_6ac7e_row5_col2{
#             background-color: yellow;
#         }#T_6ac7e_row1_col0,#T_6ac7e_row1_col1,#T_6ac7e_row1_col2,#T_6ac7e_row2_col0,#T_6ac7e_row2_col1,#T_6ac7e_row3_col1,#T_6ac7e_row3_col2,#T_6ac7e_row4_col2,#T_6ac7e_row5_col0,#T_6ac7e_row5_col1{
#             background-color: #F5C48F;
#         }#T_6ac7e_row3_col0{
#             background-color: orange;
#         }</style><table id="T_6ac7e_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >A</th>        <th class="col_heading level0 col1" >B</th>        <th class="col_heading level0 col2" >C</th>        <th class="col_heading level0 col3" >D</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6ac7e_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_6ac7e_row0_col0" class="data row0 col0" >3</td>
#                         <td id="T_6ac7e_row0_col1" class="data row0 col1" >-1.251370</td>
#                         <td id="T_6ac7e_row0_col2" class="data row0 col2" >-1.353840</td>
#                         <td id="T_6ac7e_row0_col3" class="data row0 col3" >2021-02-01</td>
#             </tr>
#             <tr>
#                         <th id="T_6ac7e_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_6ac7e_row1_col0" class="data row1 col0" >1</td>
#                         <td id="T_6ac7e_row1_col1" class="data row1 col1" >0.248456</td>
#                         <td id="T_6ac7e_row1_col2" class="data row1 col2" >0.109865</td>
#                         <td id="T_6ac7e_row1_col3" class="data row1 col3" >2021-02-02</td>
#             </tr>
#             <tr>
#                         <th id="T_6ac7e_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_6ac7e_row2_col0" class="data row2 col0" >1</td>
#                         <td id="T_6ac7e_row2_col1" class="data row2 col1" >1.055555</td>
#                         <td id="T_6ac7e_row2_col2" class="data row2 col2" >-1.361628</td>
#                         <td id="T_6ac7e_row2_col3" class="data row2 col3" >2021-02-03</td>
#             </tr>
#             <tr>
#                         <th id="T_6ac7e_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_6ac7e_row3_col0" class="data row3 col0" >0</td>
#                         <td id="T_6ac7e_row3_col1" class="data row3 col1" >0.083197</td>
#                         <td id="T_6ac7e_row3_col2" class="data row3 col2" >0.771466</td>
#                         <td id="T_6ac7e_row3_col3" class="data row3 col3" >2021-02-04</td>
#             </tr>
#             <tr>
#                         <th id="T_6ac7e_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_6ac7e_row4_col0" class="data row4 col0" >3</td>
#                         <td id="T_6ac7e_row4_col1" class="data row4 col1" >-1.068152</td>
#                         <td id="T_6ac7e_row4_col2" class="data row4 col2" >1.122366</td>
#                         <td id="T_6ac7e_row4_col3" class="data row4 col3" >2021-02-05</td>
#             </tr>
#             <tr>
#                         <th id="T_6ac7e_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_6ac7e_row5_col0" class="data row5 col0" >1</td>
#                         <td id="T_6ac7e_row5_col1" class="data row5 col1" >1.025109</td>
#                         <td id="T_6ac7e_row5_col2" class="data row5 col2" >-0.753461</td>
#                         <td id="T_6ac7e_row5_col3" class="data row5 col3" >2021-02-06</td>
#             </tr>
#     </tbody></table>

# %%
data.apply_mask_background_colors_to_excel()
