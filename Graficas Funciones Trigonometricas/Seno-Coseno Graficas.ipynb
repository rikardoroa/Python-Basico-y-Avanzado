# %%
"Script por @rikardoroa"
"Graficas correspondientes a problemas con seno y conseno utilizando los metodos Linspace y Arange de Numpy"
import numpy as np
import matplotlib.pyplot as plt


def grafica_seno_coseno():
    x = np.arange(-4,2*np.pi, 0.3)
    y = 2*np.sin(x)
    y2 = 3*np.cos(x)
    ptl.plot(x, y,  '-gD')
    ptl.plot(x, y2, '-rD')
    ptl.grid(True)
    return ptl.show()

# %%
grafica_seno_coseno()

# %%
def grafica_seno_coseno2():
    x = np.linspace(-4, 6, 30)
    y = 2*np.sin(x)
    y2 = 3*np.cos(x)
    ptl.plot(x, y,  '-gD')
    ptl.plot(x, y2, '-rD')
    ptl.grid(True)
    return ptl.show()

# %%
grafica_seno_coseno2()

# %%
def grafica_seno_coseno3():
    x = np.linspace(-4, 6, 50)
    y = (2*np.sin(x)) * ( 3*np.cos(x))
    ptl.plot(x, y,  '-gD')
    ptl.grid(True)
    return ptl.show()

# %%
grafica_seno_coseno3()

# %%
def grafica_seno_coseno4():
    x = np.linspace(-4, 10, 50)
    y = (-4*np.cos(x)) * ( 2*np.sin(x)) + (3*np.cos(x))
    ptl.plot(x, y,  '-gD')
    ptl.grid(True)
    return ptl.show()

# %%
grafica_seno_coseno4()
