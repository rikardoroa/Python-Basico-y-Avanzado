# %%
import numpy as np
import matplotlib.pyplot as ptl

def leer_arrays():
    a = np.arange(7)
    b = np.arange(-6,1)
    print(a)
    print(b)
    
def imprimir_arrays_plot():
    ptl.plot(a,b)
    ptl.show()

# %%
leer_arrays()
imprimir_arrays_plot()
# Out:
# [0 1 2 3 4 5 6]
# [-6 -5 -4 -3 -2 -1  0]
